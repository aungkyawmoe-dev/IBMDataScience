# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Aung Kyaw Moe**
#
# Desired Occupation: Data Analyst

# %% [markdown]
# *I'm interested in data science because I want to work with structured and unstructured data to make them in visualize or readable formats such as bars, graphs and charts.*

# %% [markdown]
# ### This is a multiplication function for just two numbers

# %%
def multiply(a, b):
    return a * b

print(multiply(int(input("Enter first number: ")), int(input("Enter second number: "))))
# Out:
# Enter first number: 3
# Enter second number: 3
# 9

# %% [markdown]
# > This is a blocked quote.
#
# - bulleted list 1
# - bulleted list 2
# - bulleted list 3
# ---
# 1. numbered list 1
# 4. numbered list 2
# 8. numbered list 3
# ---
# ~~This is a strikethrough.~~
#
# ---
# [GoogleTranslate link](https://translate.google.com/?hl=en)
#
# ---
#
# ID  | First_Name | Last_Name |
# --- | ---        | ---       |
# 101 | Taylor     | Swift     |
# 102 | Cristiano  | Ronaldo   |
# 103 | Lionel     | Messi     |
